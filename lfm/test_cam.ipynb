# %%
from opm_acquire import cams
from pyDCAM import *

# %%
from pyDCAM import *

device_count = dcamapi_init()
print("dcamapi_init() found {} device(s).".format(device_count))

for i_device in range(device_count):
    with HDCAM(i_device) as hdcam:
        model = hdcam.dcamdev_getstring(DCAM_IDSTR.DCAM_IDSTR_MODEL)
        camera_id = hdcam.dcamdev_getstring(DCAM_IDSTR.DCAM_IDSTR_CAMERAID)
        bus = hdcam.dcamdev_getstring(DCAM_IDSTR.DCAM_IDSTR_BUS)

    print("{} ({}) on {}".format(model, camera_id, bus))

# dcamapi_uninit()
# Out:
# ---------------------------------------------------------------------------
# DCAMError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pyDCAM import *
# ----> 3 device_count = dcamapi_init()
#       4 print("dcamapi_init() found {} device(s).".format(device_count))
#       6 for i_device in range(device_count):
#
# File ~\Desktop\dcam\pydcam\pyDCAM\dcamapi.py:57, in dcamapi_init()
#      55 param.initoption = None
#      56 param.guid = None
# ---> 57 check_status(dcamapi.dcamapi_init(ctypes.byref(param)))
#      58 return param.iDeviceCount
#
# File ~\Desktop\dcam\pydcam\pyDCAM\dcamapi.py:42, in check_status(dcamerr)
#      40 def check_status(dcamerr):
#      41     if not dcamerr == DCAMERR.DCAMERR_SUCCESS:
# ---> 42         raise DCAMError(dcamerr)
#
# DCAMError: DCAMERR_NOCAMERA

# %%
range(device_count)[0]
# Out:
# 0

# %%
hdcam= HDCAM(0)

# %%
with use_dcamapi:
    with HDCAM(i_device) as hdcam:
        for prop_id in hdcam.dcamprop_ids():
            name = hdcam.dcamprop_getname(prop_id)
            value = hdcam.dcamprop_getvalue(prop_id)
            

            print(prop_id, name, value)
# Out:
# 4194832 SENSOR MODE 1.0
# 4194576 READOUT SPEED 2.0
# 4194608 READOUT DIRECTION 5.0
# 4325664 COLORTYPE 1.0
# 4325680 BIT PER CHANNEL 16.0
# 1048848 TRIGGER SOURCE 1.0
# 1049104 TRIGGER MODE 1.0
# 1048864 TRIGGER ACTIVE 1.0
# 2032384 TRIGGER GLOBAL EXPOSURE 3.0
# 1049120 TRIGGER POLARITY 1.0
# 1049136 TRIGGER CONNECTOR 2.0
# 1049152 TRIGGER TIMES 1.0
# 1049184 TRIGGER DELAY 0.0
# 1049200 INTERNAL TRIGGER HANDLING 1.0
# 2097936 SENSOR TEMPERATURE -10.0
# 2097984 SENSOR COOLER STATUS 2.0
# 2031888 EXPOSURE TIME 0.009997714285714287
# 4653072 DEFECT CORRECT MODE 2.0
# 4653104 HOT PIXEL CORRECT LEVEL 1.0
# 4198672 BINNING 1.0
# 4202768 SUBARRAY HPOS 0.0
# 4202784 SUBARRAY HSIZE 2048.0
# 4202800 SUBARRAY VPOS 0.0
# 4202816 SUBARRAY VSIZE 2048.0
# 4202832 SUBARRAY MODE 1.0
# 3671312 INTENSITY LUT MODE 1.0
# 3671328 INTENSITY LUT PAGE 1.0
# 4195872 EXTRACTION MODE 1.0
# 4206608 TIMING READOUT TIME 0.024994285714285715
# 4206624 TIMING CYCLIC TRIGGER PERIOD 0.0
# 4206640 TIMING MIN TRIGGER BLANKING 0.0
# 4206672 TIMING MIN TRIGGER INTERVAL 0.024994285714285715
# 4206736 TIMING GLOBAL EXPOSURE DELAY 0.014996571428571429
# 4206688 TIMING EXPOSURE 3.0
# 4206704 TIMING INVALID EXPOSURE PERIOD 0.014996571428571429
# 4208656 INTERNAL FRAME RATE 40.00914494741655
# 4208672 INTERNAL FRAME INTERVAL 0.024994285714285715
# 4208704 INTERNAL LINE SPEED 0.6670524691358024
# 4208720 INTERNAL LINE INTERVAL 9.74436090225564e-06
# 4329488 FRAMEBUNDLE MODE 1.0
# 4329504 FRAMEBUNDLE NUMBER 2.0
# 4329520 FRAMEBUNDLE ROWBYTES 4096.0
# 4329536 FRAMEBUNDLE FRAME STEP BYTES 8388608.0
# 4325904 IMAGE WIDTH 2048.0
# 4325920 IMAGE HEIGHT 2048.0
# 4325936 IMAGE ROWBYTES 4096.0
# 4325952 IMAGE FRAMEBYTES 8388608.0
# 4325968 IMAGE TOP OFFSET BYTES 0.0
# 4326000 IMAGE PIXEL TYPE 2.0
# 4326144 IMAGE CAMERA STAMP 0.0
# 4326192 BUFFER ROWBYTES 4096.0
# 4326208 BUFFER FRAMEBYTES 8388608.0
# 4326224 BUFFER TOP OFFSET BYTES 0.0
# 4326240 BUFFER PIXEL TYPE 2.0
# 4326416 RECORD FIXED BYTES PER FILE 256.0
# 4326432 RECORD FIXED BYTES PER SESSION 800.0
# 4326448 RECORD FIXED BYTES PER FRAME 8388656.0
# 1835024 NUMBER OF OUTPUT TRIGGER CONNECTOR 3.0
# 1835280 OUTPUT TRIGGER SOURCE[0] 2.0
# 1835296 OUTPUT TRIGGER POLARITY[0] 1.0
# 1835312 OUTPUT TRIGGER ACTIVE[0] 1.0
# 1835328 OUTPUT TRIGGER DELAY[0] 0.0
# 1835344 OUTPUT TRIGGER PERIOD[0] 1e-06
# 1835360 OUTPUT TRIGGER KIND[0] 1.0
# 1835376 OUTPUT TRIGGER BASE SENSOR[0] 16.0
# 1835408 OUTPUT TRIGGER PRE HSYNC COUNT 0.0
# 1966112 MASTER PULSE MODE 1.0
# 1966128 MASTER PULSE TRIGGER SOURCE 1.0
# 1966144 MASTER PULSE INTERVAL 0.09999999999999999
# 1966160 MASTER PULSE BURST TIMES 1.0
# 16711696 SYSTEM ALIVE 2.0
# 16769040 CONVERSION FACTOR COEFF 0.47000000000000003
# 16769056 CONVERSION FACTOR OFFSET 100.0
# 4325824 NUMBER OF VIEW 1.0
# 4327440 IMAGE DETECTOR PIXEL WIDTH 6.5
# 4327456 IMAGE DETECTOR PIXEL HEIGHT 6.5
# 4327472 IMAGE DETECTOR PIXEL NUM HORZ 2048.0
# 4327488 IMAGE DETECTOR PIXEL NUM VERT 2048.0
# 4262416 TIME STAMP PRODUCER 5.0
# 4262432 FRAME STAMP PRODUCER 5.0

# %%
with use_dcamapi:
    with HDCAM(i_device) as hdcam:
        d = dict(horzsize = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_IMAGE_HEIGHT),
                vertsize = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_IMAGE_WIDTH),
                yoffs = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_SUBARRAYHPOS),
                xoffs = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_SUBARRAYVPOS),
                sens_h = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_SUBARRAYVPOS),
                exposure = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_EXPOSURETIME),
                exposure_ratio = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_EXPOSURETIME_RATIO),
        )
d
# Out:
# ---------------------------------------------------------------------------
# DCAMError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 with use_dcamapi:
#       2     with HDCAM(i_device) as hdcam:
#       3         d = dict(horzsize = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_IMAGE_HEIGHT),
#       4                 vertsize = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_IMAGE_WIDTH),
#       5                 yoffs = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_SUBARRAYHPOS),
#    (...)
#       9                 exposure_ratio = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_EXPOSURETIME_RATIO),
#      10         )
#
# File ~\Desktop\dcam\pydcam\pyDCAM\dcamapi.py:68, in _USE_DCAMAPI.__enter__(self)
#      67 def __enter__(self):
# ---> 68     return dcamapi_init()
#
# File ~\Desktop\dcam\pydcam\pyDCAM\dcamapi.py:57, in dcamapi_init()
#      55 param.initoption = None
#      56 param.guid = None
# ---> 57 check_status(dcamapi.dcamapi_init(ctypes.byref(param)))
#      58 return param.iDeviceCount
#
# File ~\Desktop\dcam\pydcam\pyDCAM\dcamapi.py:42, in check_status(dcamerr)
#      40 def check_status(dcamerr):
#      41     if not dcamerr == DCAMERR.DCAMERR_SUCCESS:
# ---> 42         raise DCAMError(dcamerr)
#
# DCAMError: DCAMERR_NOCAMERA

# %%
import matplotlib.pyplot as plt
with use_dcamapi:
    with HDCAM(i_device) as hdcam:

        # Configure the readout speed. Use slowest option for the ultraquite mode
        hdcam.readout_speed = DCAMPROPMODEVALUE.DCAMPROP_READOUTSPEED__SLOWEST

        hdcam.dcambuf_alloc(1)

        hwait = hdcam.dcamwait_open()

        hdcam.dcamcap_start()

        # Wait for the frame to be ready, it has a timeout of 1000 millisec
        hwait.dcamwait_start(timeout=1000)

        # Copy the frame from the internal buffer to create a numpy array
        array = hdcam.dcambuf_copyframe()

        # Stop the capture and release the buffer
        hdcam.dcamcap_stop()
        hdcam.dcambuf_release()

        # Display the image
        plt.imshow(array)
        plt.show()
        print(array.dtype)
        print(hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_BITSPERCHANNEL))
# Out:
# uint16
# 16.0

# %%
with use_dcamapi:
        with HDCAM(i_device) as hdcam:

            # Configure the readout speed. Use slowest option for the ultraquite mode
            hdcam.readout_speed = DCAMPROPMODEVALUE.DCAMPROP_READOUTSPEED__SLOWEST

            hdcam.subarray_mode = True # Enable subarray mode
            hdcam.subarray_size = (2048, 2048) # 100x100 pixels
            hdcam.subarray_pos = (0, 0) # 200 pixels from the top-left corner
            horzsize = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_IMAGE_HEIGHT)
            vertsize = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_IMAGE_WIDTH)
            yoffs = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_SUBARRAYHPOS)
            xoffs = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_SUBARRAYVPOS)
            print(horzsize, vertsize, yoffs, xoffs)

            hdcam.dcambuf_alloc(1)

            hwait = hdcam.dcamwait_open()

            hdcam.dcamcap_start()

            # Wait for the frame to be ready, it has a timeout of 1000 millisec
            hwait.dcamwait_start(timeout=1000)

            # Copy the frame from the internal buffer to create a numpy array
            array = hdcam.dcambuf_copyframe()

            # Stop the capture and release the buffer
            hdcam.dcamcap_stop()
            hdcam.dcambuf_release()

            # Display the image
            plt.imshow(array)
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# DCAMError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 with use_dcamapi:
#       2         with HDCAM(i_device) as hdcam:
#       3
#       4             # Configure the readout speed. Use slowest option for the ultraquite mode
# ----> 5             hdcam.readout_speed = DCAMPROPMODEVALUE.DCAMPROP_READOUTSPEED__SLOWEST
#       7             hdcam.subarray_mode = True # Enable subarray mode
#       8             hdcam.subarray_size = (2048, 2048) # 100x100 pixels
#
# File ~\Desktop\dcam\pydcam\pyDCAM\dcamapi.py:466, in HDCAM.readout_speed(self, value)
#     464 @readout_speed.setter
#     465 def readout_speed(self, value: DCAMPROPMODEVALUE):
# --> 466     self.dcamprop_setvalue(DCAMIDPROP.DCAM_IDPROP_READOUTSPEED, float(value))
#
# File ~\Desktop\dcam\pydcam\pyDCAM\dcamapi.py:201, in HDCAM.dcamprop_setvalue(self, iProp, fValue)
#     186 """Set the value of the property.
#     187
#     188 Parameters
#    (...)
#     198     an error with code DCAMERR_INVALIDPARAM is raised.
#     199 """
#     200 fValue = ctypes.c_double(float(fValue))
# --> 201 check_status(
#     202     dcamapi.dcamprop_setvalue(self.hdcam, iProp, fValue)
#     203 )
#
# File ~\Desktop\dcam\pydcam\pyDCAM\dcamapi.py:42, in check_status(dcamerr)
#      40 def check_status(dcamerr):
#      41     if not dcamerr == DCAMERR.DCAMERR_SUCCESS:
# ---> 42         raise DCAMError(dcamerr)
#
# DCAMError: DCAMERR_NOCONNECTION

# %%
from collections.abc import Callable, Iterable, Mapping
from typing import Any

import time
import threading

with use_dcamapi:
    with HDCAM(i_device) as hdcam:

        # Use the software trigger. Alternatively, use DCAMPROP_TRIGGERSOURCE__EXTERNAL
        # to use the external trigger.
        hdcam.dcamprop_setvalue(DCAMIDPROP.DCAM_IDPROP_TRIGGERSOURCE,
            DCAMPROPMODEVALUE.DCAMPROP_TRIGGERSOURCE__SOFTWARE
        )

        delay = 5

        class FireSoftwareTrigger(threading.Thread):
            def run(self):
                for i in range(delay, 0, -1):
                    print(i)
                    time.sleep(1)

                print("Firing software trigger")
                hdcam.dcamcap_firetrigger()


        hdcam.dcambuf_alloc(1)

        hwait = hdcam.dcamwait_open()

        hdcam.dcamcap_start()

        # Firing the software trigger from a separate thread
        FireSoftwareTrigger().start()

        # Blocking until the software trigger is fired
        hwait.dcamwait_start()

        array = hdcam.dcambuf_copyframe()

        hdcam.dcamcap_stop()
        hdcam.dcambuf_release()

        plt.imshow(array)
        plt.show()
# Out:
# 5
# 4
# 3
# 2
# 1
# Firing software trigger

# %%
import numpy as np
import matplotlib.pyplot as plt
ramp_samples = 100000
plt.plot(np.linspace(0, 1, ramp_samples), (1 - np.exp(-6 * np.linspace(0, 1, ramp_samples))))

# %%
import numpy as np
def dummy_npwarn_decorator_factory():
  def npwarn_decorator(x):
    return x
  return npwarn_decorator
np._no_nep50_warning = getattr(np, '_no_nep50_warning', dummy_npwarn_decorator_factory)
from pylablib.devices.DCAM import DCAMCamera
cam = DCAMCamera()

# %%
cam.get_all_attribute_values()
# Out:
# Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 8388608
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 4096
# 'buffer_top_offset_bytes': 0
# 'colortype': 1
# 'conversion_factor_coeff': 0.47000000000000003
# 'conversion_factor_offset': 100.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.009997714285714287
# 'extraction_mode': 1
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 8388608
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 4096
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 6.5
# 'image_detector_pixel_num_horz': 2048
# 'image_detector_pixel_num_vert': 2048
# 'image_detector_pixel_width': 6.5
# 'image_framebytes': 8388608
# 'image_height': 2048
# 'image_pixel_type': 2
# 'image_rowbytes': 4096
# 'image_top_offset_bytes': 0
# 'image_width': 2048
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.024994285714285715
# 'internal_frame_rate': 40.00914494741655
# 'internal_line_interval': 9.74436090225564e-06
# 'internal_line_speed': 0.6670524691358024
# 'internal_trigger_handling': 1
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.09999999999999999
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'number_of_view': 1
# 'output_trigger_active[0]': 1
# 'output_trigger_base_sensor[0]': 16
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 1e-06
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 5
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 8388656
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -10.0
# 'subarray_hpos': 0
# 'subarray_hsize': 2048
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2048
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 0.014996571428571429
# 'timing_invalid_exposure_period': 0.014996571428571429
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.024994285714285715
# 'timing_readout_time': 0.024994285714285715
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)

# %%
from pylablib.devices.DCAM import DCAMCamera

# %%
cam = DCAMCamera()

# %%
cam.open()

# %%
cam.get_roi()
# Out:
# (0, 2048, 0, 2048, 1, 1)

# %%
cam.get_all_attributes()
# Out:
# Dictionary('binning': DCAMAttribute(name='BINNING', kind=enum, id=4198672, min=1, max=4, unit=0)
# 'bit_per_channel': DCAMAttribute(name='BIT PER CHANNEL', kind=int, id=4325680, min=12, max=16, unit=0)
# 'buffer_framebytes': DCAMAttribute(name='BUFFER FRAMEBYTES', kind=int, id=4326208, min=2, max=8388608, unit=0)
# 'buffer_pixel_type': DCAMAttribute(name='BUFFER PIXEL TYPE', kind=enum, id=4326240, min=1, max=3, unit=0)
# 'buffer_rowbytes': DCAMAttribute(name='BUFFER ROWBYTES', kind=int, id=4326192, min=2, max=4096, unit=0)
# 'buffer_top_offset_bytes': DCAMAttribute(name='BUFFER TOP OFFSET BYTES', kind=int, id=4326224, min=0, max=0, unit=0)
# 'colortype': DCAMAttribute(name='COLORTYPE', kind=enum, id=4325664, min=1, max=1, unit=0)
# 'conversion_factor_coeff': DCAMAttribute(name='CONVERSION FACTOR COEFF', kind=float, id=16769040, min=0.0, max=255.99, unit=0)
# 'conversion_factor_offset': DCAMAttribute(name='CONVERSION FACTOR OFFSET', kind=float, id=16769056, min=-65535.0, max=65535.0, unit=0)
# 'defect_correct_mode': DCAMAttribute(name='DEFECT CORRECT MODE', kind=enum, id=4653072, min=1, max=2, unit=0)
# 'exposure_time': DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=0.0010036691729323308, max=10.000004210526317, unit=1)
# 'extraction_mode': DCAMAttribute(name='EXTRACTION MODE', kind=enum, id=4195872, min=1, max=1, unit=0)
# 'frame_stamp_producer': DCAMAttribute(name='FRAME STAMP PRODUCER', kind=enum, id=4262432, min=5, max=5, unit=0)
# 'framebundle_frame_step_bytes': DCAMAttribute(name='FRAMEBUNDLE FRAME STEP BYTES', kind=int, id=4329536, min=8388608, max=8388608, unit=0)
# 'framebundle_mode': DCAMAttribute(name='FRAMEBUNDLE MODE', kind=enum, id=4329488, min=1, max=1, unit=0)
# 'framebundle_number': DCAMAttribute(name='FRAMEBUNDLE NUMBER', kind=int, id=4329504, min=2, max=2, unit=0)
# 'framebundle_rowbytes': DCAMAttribute(name='FRAMEBUNDLE ROWBYTES', kind=int, id=4329520, min=4096, max=4096, unit=0)
# 'hot_pixel_correct_level': DCAMAttribute(name='HOT PIXEL CORRECT LEVEL', kind=enum, id=4653104, min=1, max=3, unit=0)
# 'image_camera_stamp': DCAMAttribute(name='IMAGE CAMERA STAMP', kind=int, id=4326144, min=0, max=65535, unit=0)
# 'image_detector_pixel_height': DCAMAttribute(name='IMAGE DETECTOR PIXEL HEIGHT', kind=float, id=4327456, min=6.5, max=6.5, unit=7)
# 'image_detector_pixel_num_horz': DCAMAttribute(name='IMAGE DETECTOR PIXEL NUM HORZ', kind=int, id=4327472, min=2048, max=2048, unit=0)
# 'image_detector_pixel_num_vert': DCAMAttribute(name='IMAGE DETECTOR PIXEL NUM VERT', kind=int, id=4327488, min=2048, max=2048, unit=0)
# 'image_detector_pixel_width': DCAMAttribute(name='IMAGE DETECTOR PIXEL WIDTH', kind=float, id=4327440, min=6.5, max=6.5, unit=7)
# 'image_framebytes': DCAMAttribute(name='IMAGE FRAMEBYTES', kind=int, id=4325952, min=2, max=8388608, unit=0)
# 'image_height': DCAMAttribute(name='IMAGE HEIGHT', kind=int, id=4325920, min=4, max=2048, unit=0)
# 'image_pixel_type': DCAMAttribute(name='IMAGE PIXEL TYPE', kind=enum, id=4326000, min=1, max=3, unit=0)
# 'image_rowbytes': DCAMAttribute(name='IMAGE ROWBYTES', kind=int, id=4325936, min=2, max=4096, unit=0)
# 'image_top_offset_bytes': DCAMAttribute(name='IMAGE TOP OFFSET BYTES', kind=int, id=4325968, min=0, max=0, unit=0)
# 'image_width': DCAMAttribute(name='IMAGE WIDTH', kind=int, id=4325904, min=4, max=2048, unit=0)
# 'intensity_lut_mode': DCAMAttribute(name='INTENSITY LUT MODE', kind=enum, id=3671312, min=1, max=2, unit=0)
# 'intensity_lut_page': DCAMAttribute(name='INTENSITY LUT PAGE', kind=enum, id=3671328, min=1, max=1, unit=0)
# 'internal_frame_interval': DCAMAttribute(name='INTERNAL FRAME INTERVAL', kind=float, id=4208672, min=0.024994285714285715, max=10.000004210526317, unit=1)
# 'internal_frame_rate': DCAMAttribute(name='INTERNAL FRAME RATE', kind=float, id=4208656, min=0.09999995789475456, max=40.00914494741655, unit=5)
# 'internal_line_interval': DCAMAttribute(name='INTERNAL LINE INTERVAL', kind=float, id=4208720, min=9.74436090225564e-06, max=9.74436090225564e-06, unit=1)
# 'internal_line_speed': DCAMAttribute(name='INTERNAL LINE SPEED', kind=float, id=4208704, min=0.6670524691358024, max=0.6670524691358024, unit=4)
# 'internal_trigger_handling': DCAMAttribute(name='INTERNAL TRIGGER HANDLING', kind=enum, id=1049200, min=1, max=1, unit=0)
# 'master_pulse_burst_times': DCAMAttribute(name='MASTER PULSE BURST TIMES', kind=int, id=1966160, min=1, max=10000, unit=0)
# 'master_pulse_interval': DCAMAttribute(name='MASTER PULSE INTERVAL', kind=float, id=1966144, min=9.999999999999999e-06, max=10.0, unit=1)
# 'master_pulse_mode': DCAMAttribute(name='MASTER PULSE MODE', kind=enum, id=1966112, min=1, max=3, unit=0)
# 'master_pulse_trigger_source': DCAMAttribute(name='MASTER PULSE TRIGGER SOURCE', kind=enum, id=1966128, min=1, max=2, unit=0)
# 'number_of_output_trigger_connector': DCAMAttribute(name='NUMBER OF OUTPUT TRIGGER CONNECTOR', kind=int, id=1835024, min=3, max=3, unit=0)
# 'number_of_view': DCAMAttribute(name='NUMBER OF VIEW', kind=int, id=4325824, min=1, max=2, unit=0)
# 'output_trigger_active[0]': DCAMAttribute(name='OUTPUT TRIGGER ACTIVE[0]', kind=enum, id=1835312, min=1, max=1, unit=0)
# 'output_trigger_base_sensor[0]': DCAMAttribute(name='OUTPUT TRIGGER BASE SENSOR[0]', kind=enum, id=1835376, min=1, max=16, unit=0)
# 'output_trigger_delay[0]': DCAMAttribute(name='OUTPUT TRIGGER DELAY[0]', kind=float, id=1835328, min=0.0, max=10.0, unit=1)
# 'output_trigger_kind[0]': DCAMAttribute(name='OUTPUT TRIGGER KIND[0]', kind=enum, id=1835360, min=1, max=5, unit=0)
# 'output_trigger_period[0]': DCAMAttribute(name='OUTPUT TRIGGER PERIOD[0]', kind=float, id=1835344, min=1e-06, max=10.0, unit=1)
# 'output_trigger_polarity[0]': DCAMAttribute(name='OUTPUT TRIGGER POLARITY[0]', kind=enum, id=1835296, min=1, max=2, unit=0)
# 'output_trigger_pre_hsync_count': DCAMAttribute(name='OUTPUT TRIGGER PRE HSYNC COUNT', kind=int, id=1835408, min=0, max=2047, unit=0)
# 'output_trigger_source[0]': DCAMAttribute(name='OUTPUT TRIGGER SOURCE[0]', kind=enum, id=1835280, min=2, max=6, unit=0)
# 'readout_direction': DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=5, max=5, unit=0)
# 'readout_speed': DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0)
# 'record_fixed_bytes_per_file': DCAMAttribute(name='RECORD FIXED BYTES PER FILE', kind=int, id=4326416, min=256, max=256, unit=0)
# 'record_fixed_bytes_per_frame': DCAMAttribute(name='RECORD FIXED BYTES PER FRAME', kind=int, id=4326448, min=0, max=8388688, unit=0)
# 'record_fixed_bytes_per_session': DCAMAttribute(name='RECORD FIXED BYTES PER SESSION', kind=int, id=4326432, min=0, max=1104, unit=0)
# 'sensor_cooler_status': DCAMAttribute(name='SENSOR COOLER STATUS', kind=enum, id=2097984, min=1, max=3, unit=0)
# 'sensor_mode': DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=16, unit=0)
# 'sensor_temperature': DCAMAttribute(name='SENSOR TEMPERATURE', kind=float, id=2097936, min=-50.0, max=100.0, unit=2)
# 'subarray_hpos': DCAMAttribute(name='SUBARRAY HPOS', kind=int, id=4202768, min=0, max=2044, unit=0)
# 'subarray_hsize': DCAMAttribute(name='SUBARRAY HSIZE', kind=int, id=4202784, min=4, max=2048, unit=0)
# 'subarray_mode': DCAMAttribute(name='SUBARRAY MODE', kind=enum, id=4202832, min=1, max=2, unit=0)
# 'subarray_vpos': DCAMAttribute(name='SUBARRAY VPOS', kind=int, id=4202800, min=0, max=2044, unit=0)
# 'subarray_vsize': DCAMAttribute(name='SUBARRAY VSIZE', kind=int, id=4202816, min=4, max=2048, unit=0)
# 'system_alive': DCAMAttribute(name='SYSTEM ALIVE', kind=enum, id=16711696, min=1, max=2, unit=0)
# 'time_stamp_producer': DCAMAttribute(name='TIME STAMP PRODUCER', kind=enum, id=4262416, min=5, max=5, unit=0)
# 'timing_cyclic_trigger_period': DCAMAttribute(name='TIMING CYCLIC TRIGGER PERIOD', kind=float, id=4206624, min=0.0, max=0.0, unit=1)
# 'timing_exposure': DCAMAttribute(name='TIMING EXPOSURE', kind=enum, id=4206688, min=1, max=3, unit=0)
# 'timing_global_exposure_delay': DCAMAttribute(name='TIMING GLOBAL EXPOSURE DELAY', kind=float, id=4206736, min=0.0, max=0.024994285714285715, unit=1)
# 'timing_invalid_exposure_period': DCAMAttribute(name='TIMING INVALID EXPOSURE PERIOD', kind=float, id=4206704, min=0.0, max=0.014996571428571429, unit=1)
# 'timing_min_trigger_blanking': DCAMAttribute(name='TIMING MIN TRIGGER BLANKING', kind=float, id=4206640, min=0.0, max=0.0, unit=1)
# 'timing_min_trigger_interval': DCAMAttribute(name='TIMING MIN TRIGGER INTERVAL', kind=float, id=4206672, min=0.0, max=0.0, unit=1)
# 'timing_readout_time': DCAMAttribute(name='TIMING READOUT TIME', kind=float, id=4206608, min=0.0, max=0.0, unit=1)
# 'trigger_active': DCAMAttribute(name='TRIGGER ACTIVE', kind=enum, id=1048864, min=1, max=3, unit=0)
# 'trigger_connector': DCAMAttribute(name='TRIGGER CONNECTOR', kind=enum, id=1049136, min=2, max=2, unit=0)
# 'trigger_delay': DCAMAttribute(name='TRIGGER DELAY', kind=float, id=1049184, min=0.0, max=10.000003999999999, unit=1)
# 'trigger_global_exposure': DCAMAttribute(name='TRIGGER GLOBAL EXPOSURE', kind=enum, id=2032384, min=3, max=5, unit=0)
# 'trigger_mode': DCAMAttribute(name='TRIGGER MODE', kind=enum, id=1049104, min=1, max=6, unit=0)
# 'trigger_polarity': DCAMAttribute(name='TRIGGER POLARITY', kind=enum, id=1049120, min=1, max=2, unit=0)
# 'trigger_source': DCAMAttribute(name='TRIGGER SOURCE', kind=enum, id=1048848, min=1, max=4, unit=0)
# 'trigger_times': DCAMAttribute(name='TRIGGER TIMES', kind=int, id=1049152, min=1, max=10000, unit=0))

# %%
cam.get_full_info()
# Out:
# {'image_indexing': 'rct',
#  'frame_format': 'list',
#  'frame_info_format': 'namedtuple',
#  'frame_info_period': 1,
#  'roi': (0, 2048, 0, 2048, 1, 1),
#  'trigger_mode': 'int',
#  'ext_trigger': (False, 0.0),
#  'readout_speed': 'fast',
#  'defect_correct_mode': True,
#  'exposure': 0.009997714285714287,
#  'buffer_size': 0,
#  'acquired_frames': 0,
#  'acquisition_in_progress': False,
#  'frames_status': TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0),
#  'data_dimensions': (2048, 2048),
#  'frame_timings': TAcqTimings(exposure=0.009997714285714287, frame_period=0.024994285714285715),
#  'roi_limits': (TAxisROILimit(min=4, max=2048, pstep=4, sstep=4, maxbin=4),
#   TAxisROILimit(min=4, max=2048, pstep=4, sstep=4, maxbin=4)),
#  'readout_time': 0.024994285714285715,
#  'acq_status': 'unstable',
#  'transfer_info': (-1, 0),
#  'frame_period': 0.024994285714285715,
#  'cls': 'DCAMCamera',
#  'conn': 0,
#  'detector_size': (2048, 2048),
#  'frame_info_fields': ['frame_index',
#   'framestamp',
#   'timestamp_us',
#   'camerastamp',
#   'position_left',
#   'position_top',
#   'pixeltype'],
#  'device_info': TDeviceInfo(vendor='Hamamatsu', model='C13440-20CU', serial_number='S/N: 302496', camera_version='4.30.B'),
#  'all_trigger_modes': ['int', 'ext', 'software', 'master_pulse'],
#  'all_readout_speeds': ['slow', 'fast']}

# %%
cam.is_acquisition_setup()
# Out:
# True

# %%
cam.start_acquisition(nframes=199)

# %%
cam.stop_acquisition()

# %%
cam.get_frame_format()
# Out:
# 'list'

# %%
cam.read_oldest_image()

# %%
cam.close()

# %%
cam.open()
