# %%
from opm_acquire import cams
from pyDCAM import *

# %%
device_count = dcamapi_init()
print("dcamapi_init() found {} device(s).".format(device_count))

for i_device in range(device_count):
    with HDCAM(i_device) as hdcam:
        model = hdcam.dcamdev_getstring(DCAM_IDSTR.DCAM_IDSTR_MODEL)
        camera_id = hdcam.dcamdev_getstring(DCAM_IDSTR.DCAM_IDSTR_CAMERAID)
        bus = hdcam.dcamdev_getstring(DCAM_IDSTR.DCAM_IDSTR_BUS)

    print("{} ({}) on {}".format(model, camera_id, bus))

dcamapi_uninit()
# Out:
# dcamapi_init() found 1 device(s).
# C13440-20CU (S/N: 302496) on USB3

# %%
with use_dcamapi:
    with HDCAM(i_device) as hdcam:
        for prop_id in hdcam.dcamprop_ids():
            name = hdcam.dcamprop_getname(prop_id)
            value = hdcam.dcamprop_getvalue(prop_id)
            

            print(prop_id, name, value)
# Out:
# 4194832 SENSOR MODE 1.0
# 4194576 READOUT SPEED 2.0
# 4194608 READOUT DIRECTION 5.0
# 4325664 COLORTYPE 1.0
# 4325680 BIT PER CHANNEL 16.0
# 1048848 TRIGGER SOURCE 1.0
# 1049104 TRIGGER MODE 1.0
# 1048864 TRIGGER ACTIVE 1.0
# 2032384 TRIGGER GLOBAL EXPOSURE 3.0
# 1049120 TRIGGER POLARITY 1.0
# 1049136 TRIGGER CONNECTOR 2.0
# 1049152 TRIGGER TIMES 1.0
# 1049184 TRIGGER DELAY 0.0
# 1049200 INTERNAL TRIGGER HANDLING 1.0
# 2097936 SENSOR TEMPERATURE -10.0
# 2097984 SENSOR COOLER STATUS 2.0
# 2031888 EXPOSURE TIME 0.009997714285714287
# 4653072 DEFECT CORRECT MODE 2.0
# 4653104 HOT PIXEL CORRECT LEVEL 1.0
# 4198672 BINNING 1.0
# 4202768 SUBARRAY HPOS 0.0
# 4202784 SUBARRAY HSIZE 2048.0
# 4202800 SUBARRAY VPOS 0.0
# 4202816 SUBARRAY VSIZE 2048.0
# 4202832 SUBARRAY MODE 1.0
# 3671312 INTENSITY LUT MODE 1.0
# 3671328 INTENSITY LUT PAGE 1.0
# 4195872 EXTRACTION MODE 1.0
# 4206608 TIMING READOUT TIME 0.024994285714285715
# 4206624 TIMING CYCLIC TRIGGER PERIOD 0.0
# 4206640 TIMING MIN TRIGGER BLANKING 0.0
# 4206672 TIMING MIN TRIGGER INTERVAL 0.024994285714285715
# 4206736 TIMING GLOBAL EXPOSURE DELAY 0.014996571428571429
# 4206688 TIMING EXPOSURE 3.0
# 4206704 TIMING INVALID EXPOSURE PERIOD 0.014996571428571429
# 4208656 INTERNAL FRAME RATE 40.00914494741655
# 4208672 INTERNAL FRAME INTERVAL 0.024994285714285715
# 4208704 INTERNAL LINE SPEED 0.6670524691358024
# 4208720 INTERNAL LINE INTERVAL 9.74436090225564e-06
# 4329488 FRAMEBUNDLE MODE 1.0
# 4329504 FRAMEBUNDLE NUMBER 2.0
# 4329520 FRAMEBUNDLE ROWBYTES 4096.0
# 4329536 FRAMEBUNDLE FRAME STEP BYTES 8388608.0
# 4325904 IMAGE WIDTH 2048.0
# 4325920 IMAGE HEIGHT 2048.0
# 4325936 IMAGE ROWBYTES 4096.0
# 4325952 IMAGE FRAMEBYTES 8388608.0
# 4325968 IMAGE TOP OFFSET BYTES 0.0
# 4326000 IMAGE PIXEL TYPE 2.0
# 4326144 IMAGE CAMERA STAMP 0.0
# 4326192 BUFFER ROWBYTES 4096.0
# 4326208 BUFFER FRAMEBYTES 8388608.0
# 4326224 BUFFER TOP OFFSET BYTES 0.0
# 4326240 BUFFER PIXEL TYPE 2.0
# 4326416 RECORD FIXED BYTES PER FILE 256.0
# 4326432 RECORD FIXED BYTES PER SESSION 800.0
# 4326448 RECORD FIXED BYTES PER FRAME 8388656.0
# 1835024 NUMBER OF OUTPUT TRIGGER CONNECTOR 3.0
# 1835280 OUTPUT TRIGGER SOURCE[0] 2.0
# 1835296 OUTPUT TRIGGER POLARITY[0] 1.0
# 1835312 OUTPUT TRIGGER ACTIVE[0] 1.0
# 1835328 OUTPUT TRIGGER DELAY[0] 0.0
# 1835344 OUTPUT TRIGGER PERIOD[0] 1e-06
# 1835360 OUTPUT TRIGGER KIND[0] 1.0
# 1835376 OUTPUT TRIGGER BASE SENSOR[0] 16.0
# 1835408 OUTPUT TRIGGER PRE HSYNC COUNT 0.0
# 1966112 MASTER PULSE MODE 1.0
# 1966128 MASTER PULSE TRIGGER SOURCE 1.0
# 1966144 MASTER PULSE INTERVAL 0.09999999999999999
# 1966160 MASTER PULSE BURST TIMES 1.0
# 16711696 SYSTEM ALIVE 2.0
# 16769040 CONVERSION FACTOR COEFF 0.47000000000000003
# 16769056 CONVERSION FACTOR OFFSET 100.0
# 4325824 NUMBER OF VIEW 1.0
# 4327440 IMAGE DETECTOR PIXEL WIDTH 6.5
# 4327456 IMAGE DETECTOR PIXEL HEIGHT 6.5
# 4327472 IMAGE DETECTOR PIXEL NUM HORZ 2048.0
# 4327488 IMAGE DETECTOR PIXEL NUM VERT 2048.0
# 4262416 TIME STAMP PRODUCER 5.0
# 4262432 FRAME STAMP PRODUCER 5.0

# %%
with use_dcamapi:
    with HDCAM(i_device) as hdcam:
        d = dict(horzsize = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_IMAGE_HEIGHT),
                vertsize = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_IMAGE_WIDTH),
                yoffs = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_SUBARRAYHPOS),
                xoffs = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_SUBARRAYVPOS),
                sens_h = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_SUBARRAYVPOS),
                exposure = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_EXPOSURETIME),
                exposure_ratio = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_EXPOSURETIME_RATIO),
        )
d
# Out:
# {'horzsize': 2048.0,
#  'vertsize': 2048.0,
#  'yoffs': 0.0,
#  'xoffs': 0.0,
#  'sens_h': 0.0,
#  'exposure': 0.009997714285714287,
#  'exposure_ratio': 1.0}

# %%
import matplotlib.pyplot as plt
with use_dcamapi:
    with HDCAM(i_device) as hdcam:

        # Configure the readout speed. Use slowest option for the ultraquite mode
        hdcam.readout_speed = DCAMPROPMODEVALUE.DCAMPROP_READOUTSPEED__SLOWEST

        hdcam.dcambuf_alloc(1)

        hwait = hdcam.dcamwait_open()

        hdcam.dcamcap_start()

        # Wait for the frame to be ready, it has a timeout of 1000 millisec
        hwait.dcamwait_start(timeout=1000)

        # Copy the frame from the internal buffer to create a numpy array
        array = hdcam.dcambuf_copyframe()

        # Stop the capture and release the buffer
        hdcam.dcamcap_stop()
        hdcam.dcambuf_release()

        # Display the image
        plt.imshow(array)
        plt.show()
        print(array.dtype)
        print(hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_BITSPERCHANNEL))
# Out:
# uint16
# 16.0

# %%
with use_dcamapi:
        with HDCAM(i_device) as hdcam:

            # Configure the readout speed. Use slowest option for the ultraquite mode
            hdcam.readout_speed = DCAMPROPMODEVALUE.DCAMPROP_READOUTSPEED__SLOWEST

            hdcam.subarray_mode = True # Enable subarray mode
            hdcam.subarray_size = (100, 100) # 100x100 pixels
            hdcam.subarray_pos = (200, 200) # 200 pixels from the top-left corner
            horzsize = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_IMAGE_HEIGHT)
            vertsize = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_IMAGE_WIDTH)
            yoffs = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_SUBARRAYHPOS)
            xoffs = hdcam.dcamprop_getvalue(DCAMIDPROP.DCAM_IDPROP_SUBARRAYVPOS)
            print(horzsize, vertsize, yoffs, xoffs)

            hdcam.dcambuf_alloc(1)

            hwait = hdcam.dcamwait_open()

            hdcam.dcamcap_start()

            # Wait for the frame to be ready, it has a timeout of 1000 millisec
            hwait.dcamwait_start(timeout=1000)

            # Copy the frame from the internal buffer to create a numpy array
            array = hdcam.dcambuf_copyframe()

            # Stop the capture and release the buffer
            hdcam.dcamcap_stop()
            hdcam.dcambuf_release()

            # Display the image
            plt.imshow(array)
            plt.show()
# Out:
# 100.0 100.0 200.0 200.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 33
#      30 hdcam.dcambuf_release()
#      32 # Display the image
# ---> 33 plt.imshow(array)
#      34 plt.show()
#
# NameError: name 'plt' is not defined

# %%
from collections.abc import Callable, Iterable, Mapping
from typing import Any

import time
import threading

with use_dcamapi:
    with HDCAM(i_device) as hdcam:

        # Use the software trigger. Alternatively, use DCAMPROP_TRIGGERSOURCE__EXTERNAL
        # to use the external trigger.
        hdcam.dcamprop_setvalue(DCAMIDPROP.DCAM_IDPROP_TRIGGERSOURCE,
            DCAMPROPMODEVALUE.DCAMPROP_TRIGGERSOURCE__SOFTWARE
        )

        delay = 5

        class FireSoftwareTrigger(threading.Thread):
            def run(self):
                for i in range(delay, 0, -1):
                    print(i)
                    time.sleep(1)

                print("Firing software trigger")
                hdcam.dcamcap_firetrigger()


        hdcam.dcambuf_alloc(1)

        hwait = hdcam.dcamwait_open()

        hdcam.dcamcap_start()

        # Firing the software trigger from a separate thread
        FireSoftwareTrigger().start()

        # Blocking until the software trigger is fired
        hwait.dcamwait_start()

        array = hdcam.dcambuf_copyframe()

        hdcam.dcamcap_stop()
        hdcam.dcambuf_release()

        plt.imshow(array)
        plt.show()
# Out:
# 5
# 4
# 3
# 2
# 1
# Firing software trigger

# %%
import numpy as np
import matplotlib.pyplot as plt
ramp_samples = 100000
plt.plot(np.linspace(0, 1, ramp_samples), (1 - np.exp(-6 * np.linspace(0, 1, ramp_samples))))

# %%
import numpy as np
def dummy_npwarn_decorator_factory():
  def npwarn_decorator(x):
    return x
  return npwarn_decorator
np._no_nep50_warning = getattr(np, '_no_nep50_warning', dummy_npwarn_decorator_factory)
from pylablib.devices.DCAM import DCAMCamera
cam = DCAMCamera()

# %%
cam.get_all_attribute_values()
# Out:
# Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 8388608
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 4096
# 'buffer_top_offset_bytes': 0
# 'colortype': 1
# 'conversion_factor_coeff': 0.47000000000000003
# 'conversion_factor_offset': 100.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.009997714285714287
# 'extraction_mode': 1
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 8388608
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 4096
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 6.5
# 'image_detector_pixel_num_horz': 2048
# 'image_detector_pixel_num_vert': 2048
# 'image_detector_pixel_width': 6.5
# 'image_framebytes': 8388608
# 'image_height': 2048
# 'image_pixel_type': 2
# 'image_rowbytes': 4096
# 'image_top_offset_bytes': 0
# 'image_width': 2048
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.024994285714285715
# 'internal_frame_rate': 40.00914494741655
# 'internal_line_interval': 9.74436090225564e-06
# 'internal_line_speed': 0.6670524691358024
# 'internal_trigger_handling': 1
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.09999999999999999
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'number_of_view': 1
# 'output_trigger_active[0]': 1
# 'output_trigger_base_sensor[0]': 16
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 1e-06
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 5
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 8388656
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -10.0
# 'subarray_hpos': 0
# 'subarray_hsize': 2048
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2048
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 0.014996571428571429
# 'timing_invalid_exposure_period': 0.014996571428571429
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.024994285714285715
# 'timing_readout_time': 0.024994285714285715
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)

# %%
cam.close()

# %%
from opm_acquire.cams import CameraBase
class HanumatsuCamera(CameraBase):
    '''Hamamatsu DCAM camera using pylablib
       written by chat GPT :)
    '''
    from pylablib.devices.DCAM import DCAMCamera
    def __init__(self, conf=None):
        '''Initialize the camera'''
        self.cam = DCAMCamera()
        self.cam.open()
        self._roi = {}
        self._buffer_frames = 256
        self._fifo = True
        self._last_frame = None

    @property
    def roi(self):
        '''Get ROI as a dictionary'''
        return self._roi

    def set_roi(self, y_size=None, x_size=None, y_offset=None, x_offset=None, y_bin=1, x_bin=1):
        '''Set the Region of Interest (ROI)'''
        if y_size is not None:
            self.cam.set_property("image_height", y_size)
        if x_size is not None:
            self.cam.set_property("image_width", x_size)
        if y_offset is not None:
            self.cam.set_property("image_top", y_offset)
        if x_offset is not None:
            self.cam.set_property("image_left", x_offset)
        if y_bin is not None:
            self.cam.set_property("binning", y_bin)
        if x_bin is not None:
            self.cam.set_property("binning", x_bin)
        self._roi = {
            'y_size': y_size,
            'x_size': x_size,
            'y_offset': y_offset,
            'x_offset': x_offset,
            'y_bin': y_bin,
            'x_bin': x_bin
        }
    def set_trigger(self, external=True, each_frame=True):
        '''Set trigger mode'''
        if external:
            self.cam.set_property("trigger_source", "external")
            self.cam.set_property("trigger_active", "rising")
        else:
            self.cam.set_property("trigger_source", "internal")

    @property
    def exposure_time(self):
        '''Get the exposure time (in seconds)'''
        return self.cam.get_property("exposure_time")

    @exposure_time.setter
    def exposure_time(self, t):
        '''Set the exposure time (in seconds)'''
        self.cam.set_property("exposure_time", t)

    def arm(self, stream_to_disk_path=None, fifo=True):
        '''Start acquisition (live mode)'''
        self.cam.setup_acquisition(nframes=self._buffer_frames)
        self.cam.start_acquisition()
        self._fifo = fifo
        self._last_frame = None

    def disarm(self):
        '''Stop acquisition'''
        self.cam.stop_acquisition()

    def poll_frame(self, copy=False):
        '''Retrieve a frame from the camera'''
        frame_data = self.cam.read_newest_image()
        if frame_data is None:
            logger.warning("No frames captured")
            return None, None, None
        if copy:
            frame_data = np.copy(frame_data)
        timestamp = time.time()
        return frame_data, timestamp, None  # No direct frame count tracking available

    @property
    def frame_dtype(self):
        '''Get the data type of frames'''
        bit_depth = self.cam.get_property("image_pixeltype")
        if "16" in bit_depth:
            return "uint16"
        else:
            return "uint8"

    @property
    def frame_shape(self):
        '''Get the shape of frames (height, width)'''
        height = self.cam.get_property("image_height")
        width = self.cam.get_property("image_width")
        return (int(height), int(width))

    @property
    def sensor_shape(self):
        '''Get the full sensor resolution as (height, width)'''
        height = self.cam.get_property("sensor_height")
        width = self.cam.get_property("sensor_width")
        return (int(height), int(width))

    def __del__(self):
        '''Clean up and close camera connection'''
        self.cam.close()

# %%
cam = HanumatsuCamera()
